# %%
pip install "pymongo[srv]"
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install dnspython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymongo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Imports

import pandas as pd
from pymongo import MongoClient
# Load csv dataset
data = pd.read_csv
# Connect to MongoDB
client =  MongoClient("mongodb+srv://bina:root@cluster0.c7s0uw2.mongodb.net/?retryWrites=true&w=majority")
db = client['InformationExtraction']
collection = db['structured']
collection_str = db['structured_invoice']

# %%
import re
pattern_fahrkarte=re.compile(r'\bFahrkarte [0-9]{1,}\b')
pattern_zahlungsmittelentgelt=re.compile(r'\bZahlungsmittelentgelt\b')
pattern_Summe=re.compile(r'\Summe\b')
pattern_datum=re.compile(r'\Datum\b')
pattern_source_destination=re.compile(r'\bHinfahrt\b')

# %%
    import pandas as pd
    columns1 =[]
    columns2=[]
    columns3=[]
    columns4=[]
    data=[]
    fahr=[]
    data_frames=pd.DataFrame()
    not_applicable= 'NA NA NA NA'

# %%
def fahrkarte():

        for line11 in output.split('\n'):
            if pattern_fahrkarte.findall(line11):
                #print(line11)
                #print(type(line11))
                line11=line11.replace(' Fahrkarte','')
                return line11            


fahrkarte()
# Out:
# 'ICE 1 81,90€ 81,90€ 5,36€'

# %%
def summe():
        for line in output.split('\n'):
            if pattern_Summe.match(line):
                line=line.replace("Summe ","")
                #print(line)
                return line
summe()
# Out:
# '81,90€ 81,90€ 5,36€'

# %%
def datum():
    for line in output.split('\n'):
        if pattern_datum.match(line):
            line=line.replace("Datum ","")
            #line=line.replace(" Gen-Nr N4TM7R","")
            #print(line)
            return line
datum()
# Out:
# '11.01.2020 Gen-Nr NHGWT5'

# %%
def source_destination():
    for line in output.split('\n'):
        if pattern_source_destination.match(line):
            line=line.replace(" ,","")
            line=line.replace("Hinfahrt: ","")
            line=line.replace(" mit ICE","")
            line=line.replace(" mit IC/EC","")

            #print(line)
            return line
source_destination()
# Out:
# 'Leipzig+City  Hamburg+City'

# %%
def formTableforData():   
    
    
    
    fahr=fahrkarte().split(' ')
    src_des=source_destination().split(' ')
    #zahlungsmittel=zahlungsmittelentgelt().split(' ')
    date=datum().split(' ')
    sum_preis=summe().split(' ')
    
    columns1.append(fahr)
    col1=[{ "Positionen":a[0], "Num_Person":a[1], "Preis":a[2], "MwSt (D) 19%": a[3],"MwSt D: 7%": a[4]} for a in columns1]
    columns2.append(sum_preis)
    col2=[{ "Summe_Preis":a[0], "Summe_MwSt (D) 19%":a[1], "Summe_MwSt D: 7%":a[2]} for a in columns2]
    columns3.append(src_des)
    col3=[{ "Source":a[0], "Destination":a[2]} for a in columns3]
    columns4.append(date)
    col4=[{ "Datum":a[0]} for a in columns4]
    
    df2=pd.DataFrame(col1)
    
    df3=pd.DataFrame(col2)
    df4=pd.DataFrame(col3)
    df5=pd.DataFrame(col4)
    
    print(df2)
    print(df3)
    print(df4)
    print(df5)
    
    data_frames = [df2, df3,df4, df5]
    

    
formTableforData()
# Out:
#   Positionen Num_Person   Preis MwSt (D) 19% MwSt D: 7%
# 0        ICE          1  81,90€       81,90€      5,36€
# 1        ICE          1  81,90€       81,90€      5,36€
# 2        ICE          1  81,90€       81,90€      5,36€
# 3        ICE          1  81,90€       81,90€      5,36€
# 4        ICE          1  81,90€       81,90€      5,36€
#   Summe_Preis Summe_MwSt (D) 19% Summe_MwSt D: 7%
# 0      81,90€             81,90€            5,36€
# 1      81,90€             81,90€            5,36€
# 2      81,90€             81,90€            5,36€
# 3      81,90€             81,90€            5,36€
# 4      81,90€             81,90€            5,36€
#          Source   Destination
# 0  Leipzig+City  Hamburg+City
# 1  Leipzig+City  Hamburg+City
# 2  Leipzig+City  Hamburg+City
# 3  Leipzig+City  Hamburg+City
# 4  Leipzig+City  Hamburg+City
#         Datum
# 0  11.01.2020
# 1  11.01.2020
# 2  11.01.2020
# 3  11.01.2020
# 4  11.01.2020

# %%
import os
import PyPDF2
df=pd.DataFrame(columns=["data"])
#df_structured=pd.DataFrame(columns=["data"])
path_of_the_directory= "C:\\Users\\binakhatnani\\Downloads\\2020\\de\\public transport\\"
print("Files and directories in a specified path:")
for filename in os.listdir(path_of_the_directory):
    f = os.path.join(path_of_the_directory,filename)
    if os.path.isfile(f):
        print(f)
        reader = PyPDF2.PdfFileReader(f)
        page = reader.getPage(0)
        output = page.extractText()
        out=[]
        out.append(output)
        
        for data in out:
            df.loc[len(df)]= data
        
        
        
        print(fahrkarte())
       # print(zahlungsmittelentgelt())
        print(summe())
        print(datum())
        print(source_destination())
        
       
        
        fahr=fahrkarte().split(' ')
        src_des=source_destination().split(' ')
        #zahlungsmittel=zahlungsmittelentgelt().split(' ')
        date=datum().split(' ')
        sum_preis=summe().split(' ')
    
        df_structured=pd.DataFrame()
       
       
        df_structured.loc[1,'duration']=[[fahr],[src_des],[date],[sum_preis] ]
        print(df_structured)
       
            
       


        columns1.append(fahr)
        col1=[{ "Positionen":a[0], "Num_Person":a[1], "Preis":a[2], "MwSt (D) 19%": a[3],"MwSt D: 7%": a[4]} for a in columns1]
        columns2.append(sum_preis)
        col2=[{ "Summe_Preis":a[0], "Summe_MwSt (D) 19%":a[1], "Summe_MwSt D: 7%":a[2]} for a in columns2]
        columns3.append(src_des)
        col3=[{ "Source":a[0], "Destination":a[2]} for a in columns3]
        columns4.append(date)
        col4=[{ "Datum":a[0]} for a in columns4]

        df2=pd.DataFrame(col1)

        df3=pd.DataFrame(col2)
        df4=pd.DataFrame(col3)
        df5=pd.DataFrame(col4)

        print(df2)
        print(df3)
        print(df4)
        print(df5)
# Out:
# Files and directories in a specified path:
# C:\Users\binakhatnani\Downloads\2020\de\public transport\bahn-17B6DU.pdf
# ICE 1 81,90€ 81,90€ 5,36€
# 81,90€ 81,90€ 5,36€
# 11.01.2020 Gen-Nr NHGWT5
# Leipzig+City  Hamburg+City
#                                             duration
# 1  [[ICE, 1, 81,90€, 81,90€, 5,36€], [Leipzig+Cit...
#    Positionen Num_Person   Preis MwSt (D) 19% MwSt D: 7%
# 0         ICE          1  81,90€       81,90€      5,36€
# 1         ICE          1  81,90€       81,90€      5,36€
# 2         ICE          1  81,90€       81,90€      5,36€
# 3         ICE          1  81,90€       81,90€      5,36€
# 4         ICE          1  81,90€       81,90€      5,36€
# ..        ...        ...     ...          ...        ...
# 91        ICE          1  30,15€       30,15€      1,97€
# 92        ICE          1  89,25€       89,25€      5,84€
# 93        ICE          1  69,55€       69,55€      4,55€
# 94        ICE          1  81,90€       81,90€      5,36€
# ...

# %%
 print(df_structured.head(5))
# Out:
#                                             duration
# 1  [[ICE, 1, 81,90€, 81,90€, 5,36€], [Leipzig+Cit...

# %%
data_frames = [df,df2, df3,df4, df5]
print(data_frames)
# Out:
# [                                                data
# 0  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...
# 1  Online-Ticket\nIC/EC Fahrkarte\nFahrtantritt a...
# 2  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...
# 3  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...
# 4  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...
# 5  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...
# 6  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...
# 7  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...,   Positionen Num_Person   Preis MwSt (D) 19% MwSt D: 7%
# 0        ICE          1  81,90€       81,90€      5,36€
# 1        ICE          1  81,90€       81,90€      5,36€
# 2      IC/EC          1  72,80€       72,80€      4,76€
# 3        ICE          1  86,00€       86,00€      5,63€
# 4        ICE          1  74,30€       74,30€      4,86€
# 5        ICE          1  30,15€       30,15€      1,97€
# 6        ICE          1  89,25€       89,25€      5,84€
# ...

# %%
result = pd.concat(data_frames,axis=1)

# %%
print(result)
# Out:
#                                                 data Positionen Num_Person  \
# 0  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 1  Online-Ticket\nIC/EC Fahrkarte\nFahrtantritt a...        ICE          1
# 2  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...      IC/EC          1
# 3  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 4  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 5  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 6  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 7  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 8                                                NaN        ICE          1
#
#     Preis MwSt (D) 19% MwSt D: 7% Summe_Preis Summe_MwSt (D) 19%  \
# 0  81,90€       81,90€      5,36€      81,90€             81,90€
# 1  81,90€       81,90€      5,36€      81,90€             81,90€
# ...

# %%
#result["resu"]=f"The cost for the journey from {result["Source"]} to {result["Destination"]} on {result["Datum"]} is {result["Summe_Preis"]}"

#def concatination(row):
 #   string1="The journey from "
  #  row['Final']= "string1" +row['source'] +"to" +row['destination'] + "and the price is" +row['Summe_Preis']
   # return row['Final']

#result['Final'] = result['Final'].apply(lambda row: concatination(row) , axis=1)


result['Final'] = 'The price of jouney from '+result['Source'].astype(str) + ' to ' + result['Destination'].astype(str) + 'on ' +result['Datum'].astype(str) +'is '+ result['Summe_Preis'].astype(str)

# %%
result['Final']
result
# Out:
#                                                 data Positionen Num_Person  \
# 0  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 1  Online-Ticket\nIC/EC Fahrkarte\nFahrtantritt a...        ICE          1
# 2  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...      IC/EC          1
# 3  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 4  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 5  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 6  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 7  Online-Ticket\nICE Fahrkarte\nFahrtantritt am ...        ICE          1
# 8                                                NaN        ICE          1
#
#     Preis MwSt (D) 19% MwSt D: 7% Summe_Preis Summe_MwSt (D) 19%  \
# 0  81,90€       81,90€      5,36€      81,90€             81,90€
# 1  81,90€       81,90€      5,36€      81,90€             81,90€
# ...

# %%
result.reset_index(inplace=True)
data_dict = result.to_dict("records")
collection.insert_many(data_dict)

# %%
result.to_csv('Desktop/file_name.csv')
